# %% [markdown]
# # Matplotlib Library Studies

# %%
import matplotlib.pyplot as plt
import numpy as np

# Will lead to static images of the plot embedded in the notebook
# %matplotlib inline

x = np.linspace(0,10,100)

# Ploting a figure
fig = plt.figure()
plt.plot(x,np.sin(x),'-')
plt.plot(x,np.cos(x),'--')

# Saving a figure
fig.savefig('My_figure.png')

# %%
# Types of format supported
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
# Ploting figures
# MATLAB-style interface

# Create a plot figure
plt.figure() 

# Create the first of two panels and set current axis
plt.subplot(2,1,1) # (rows, columns, panel number)
plt.plot(x, np.sin(x));


# Create the second of two panels and set current axis
plt.subplot(2,1,2) 
plt.plot(x, np.cos(x));

# %%
# Ploting figures
# Object-oriented interface

# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2) # How to see the dim of fix and ax?

# Call plot() method on the appropriate object
ax[0].plot(x,np.sin(x))
ax[1].plot(x,np.cos(x))

# %%
# Line plots

# Style of the plot
plt.style.use('seaborn-whitegrid')

fig = plt.figure()
ax = plt.axes()

x = np.linspace(0,10,100)
ax.plot(x,np.sin(x))

# Multiple lines at the same plot
ax.plot(x,np.cos(x))
ax.plot(x,3*np.cos(x))

# %%
# Line Colors

plt.style.use('seaborn-whitegrid')

fig = plt.figure()
ax = plt.axes()

x = np.linspace(0,10,100)

plt.plot(x, np.sin(x - 0), color='blue')        # Color name
plt.plot(x, np.sin(x - 1), color='g')           # Short color name
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple
plt.plot(x, np.sin(x - 5), color='chartreuse')  # all HTML color names supported

# %%
# Line Style

plt.style.use('seaborn-whitegrid')

fig = plt.figure()
ax = plt.axes()

x = np.linspace(0,10,100)

plt.plot(x, x + 0, linestyle='-')  # solid 
plt.plot(x, x + 1, linestyle='--') # dashed 
plt.plot(x, x + 2, linestyle='-.') # dashdot
plt.plot(x, x + 3, linestyle=':')  # dotted

# %%
# Combining linestyle and color codes

plt.style.use('seaborn-whitegrid')

fig = plt.figure()
ax = plt.axes()

x = np.linspace(0,10,100)

plt.plot(x, x + 0, '-g') # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r') # dotted red

# %%
# Axes limit

plt.plot(x, np.sin(x))

# First way for limits
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)

# Another method
plt.axis([-1, 11, -1.5, 1.5])
# Out:
# (-1.0, 11.0, -1.5, 1.5)

# %%
# Labeling plots

plt.plot(x, np.sin(x))
plt.title("A Usefull Title")
plt.xlabel("x")
plt.ylabel("sin(x)")

# Creating legends for multiple lines
plt.plot(x, 2*np.sin(x), '-g', label='sin(x)')
plt.plot(x, 2*np.cos(x), ':b', label='cos(x)')

plt.legend()

# %%
# Simple Scatter Plots

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# Scatter plot with plt.plot
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black')

# %%
# Available symbols for plots

rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
        label="marker='{0}'".format(marker))
    plt.legend(numpoints=1)
    plt.xlim(0, 1.8)

# %%
# Scatter Plots with plt.scatter

rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000*rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis')
plt.colorbar() # show color scale

# %%
# Using Iris data from Scikit-Learn

# The color argument is mapped to a color scale, the size of the argument is given in pixels
# So, the color and size of points can be user to convey information illustrating multidimensional data

from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2,
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])

# Multicolor and multifeature scatter plots are useful for both exploration and presentation of data
# Out:
# /home/francisco/anaconda3/envs/Handbook_Python_DS/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Text(0, 0.5, 'sepal width (cm)')

# %%
# Visualizing Errors

plt.style.use("seaborn-whitegrid")

x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

# A normal errobar plot
#plt.errorbar(x, y, yerr=dy, fmt='.k')

# Errobars lighter than the points themselves
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
            ecolor='lightgray', elinewidth=3, capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# Continuous Errors
# A Gaussian Process Regression (GPR)

from sklearn.gaussian_process import GaussianProcessRegressor

# Define the model and draw some data
model = lambda x: x * np.sin(x)
xdata = np.array([1, 3, 5, 6, 8])
ydata = model(xdata)

# Gaussian fitting process
# Need anoter code

# %%
# Density and Contour Plots

# Visualizing a Three-Dimensional Function

def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

# Builds two-dimensional grid from one-dimensional array
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# Using contour
plt.contour(X, Y, Z, colors='black')
# Negative values are represented by dashed lines and
# positive values by solid lines

# %%
# Especifying a colormap and more lines to be draw
# RdGy -> Red-Gray Colormap

plt.contour(X, Y, Z, 20, cmap='RdGy')

# %%
# Filling the spaces between the lines with a filled contour -> plt.contourf()
# Adding a colorbar 

plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar()

# %%
# Improving the aspect of the plot by using plt.imshow()
# That interprets a two-dimensional grid of data as an image

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy', aspect='equal')
plt.colorbar()

# %%
# Combining contour and image plots

contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy', alpha=0.5)

plt.colorbar()

# %% [markdown]
# ## Histograms, Binnings and Density

# %%
# A customized Histogram

data = np.random.randn(1000)

plt.hist(data, bins=30, alpha=0.5,
         histtype='stepfilled', color='steelblue',
         edgecolor='none')
# Out:
# (array([ 2.,  3.,  9., 13., 22., 25., 34., 54., 74., 94., 82., 92., 97.,
#         97., 79., 71., 55., 40., 20., 14., 11.,  6.,  3.,  2.,  0.,  0.,
#          0.,  0.,  0.,  1.]),
#  array([-2.84645658, -2.60615315, -2.36584972, -2.12554629, -1.88524286,
#         -1.64493943, -1.404636  , -1.16433257, -0.92402914, -0.68372571,
#         -0.44342228, -0.20311885,  0.03718458,  0.27748801,  0.51779144,
#          0.75809487,  0.9983983 ,  1.23870173,  1.47900516,  1.71930859,
#          1.95961202,  2.19991545,  2.44021888,  2.68052231,  2.92082574,
#          3.16112917,  3.4014326 ,  3.64173604,  3.88203947,  4.1223429 ,
#          4.36264633]),
#  [<matplotlib.patches.Polygon at 0x7fa8a83d2a40>])

# %%
# Comparing histograms of several distributions

# Data
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([ 2.,  3.,  2.,  4.,  9., 12.,  7., 20., 18., 31., 25., 34., 33.,
#         46., 56., 55., 57., 50., 63., 62., 62., 54., 54., 42., 37., 34.,
#         39., 17., 16., 13., 14.,  4.,  6.,  4.,  4.,  2.,  5.,  1.,  0.,
#          3.]),
#  array([-2.63950334, -2.3377952 , -2.03608707, -1.73437894, -1.43267081,
#         -1.13096268, -0.82925455, -0.52754641, -0.22583828,  0.07586985,
#          0.37757798,  0.67928611,  0.98099425,  1.28270238,  1.58441051,
#          1.88611864,  2.18782677,  2.4895349 ,  2.79124304,  3.09295117,
#          3.3946593 ,  3.69636743,  3.99807556,  4.2997837 ,  4.60149183,
#          4.90319996,  5.20490809,  5.50661622,  5.80832435,  6.11003249,
#          6.41174062,  6.71344875,  7.01515688,  7.31686501,  7.61857315,
#          7.92028128,  8.22198941,  8.52369754,  8.82540567,  9.1271138 ,
#          9.42882194]),
#  [<matplotlib.patches.Polygon at 0x7fa8a8405cf0>])

# %%
# Two-Dimensional Histograms and Binnings

# Create histograms in two dimensions by dividing points among two dimensional bins
# Example with multivariate Gaussian distribution

# Data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# Two-dimensional histogram
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %%
# Hexagonal binnings
# Represents a two-dimensional dataset binned within a grid of hexagons

plt.hexbin(x, y, gridsize=30, cmap='Blues',)
cb = plt.colorbar(label='count in bin')
